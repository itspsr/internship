# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'/Users/pratiksingh/used_cars-data.csv')
df
# Out:
#        LOCATION  MNF_YEAR     BRAND          MODEL                 VARIANT  \
# 0     New Delhi      2018      Ford       Ecosport  1.5 TDCI TITANIUM PLUS
# 1     New Delhi      2016    Maruti  Vitara Brezza                 VDI OPT
# 2     New Delhi      2016      Ford       Ecosport     1.5 TITANIUM TI VCT
# 3     New Delhi      2019  Mahindra         XUV500                 W11 (O)
# 4     New Delhi      2013  Mahindra         XUV500                  W8 FWD
# ...         ...       ...       ...            ...                     ...
# 7342  Ahmedabad      2018  Mahindra    KUV 100 NXT                K2 6 STR
# 7343  Ahmedabad      2017    Maruti         Ertiga                VDI SHVS
# 7344  Ahmedabad      2019  Mahindra         XUV500                  W7 FWD
# 7345  Ahmedabad      2017      Ford       Ecosport    1.5 TITANIUMTDCI OPT
# 7346  Ahmedabad      2013    Toyota         Innova      2.5 VX 8 STR BS IV
#
#      TRANSMISSION    DRIVEN_KM FUELTYPE NO_OF_OWNERS       PRICE
# 0          Manual    55,399 km   Diesel    1st Owner   ₹8,27,999
# 1          Manual    65,904 km   Diesel    1st Owner   ₹6,55,999
# 2          Manual    27,968 km   Petrol    1st Owner   ₹6,81,699
# 3          Manual    21,014 km   Diesel    2nd Owner  ₹15,31,399
# 4          Manual    71,669 km   Diesel    1st Owner   ₹5,78,099
# ...           ...          ...      ...          ...         ...
# 7342       Manual    36,487 km   Petrol    1st Owner   ₹4,20,299
# 7343       Manual    44,087 km   Diesel    1st Owner   ₹7,84,099
# 7344       Manual    57,455 km   Diesel    1st Owner  ₹11,57,799
# 7345       Manual    59,877 km   Diesel    2nd Owner   ₹7,56,199
# 7346       Manual  2,81,379 km   Diesel    2nd Owner   ₹7,00,099
#
# [7347 rows x 10 columns]

# %%
df.dtypes
# Out:
# LOCATION        object
# MNF_YEAR         int64
# BRAND           object
# MODEL           object
# VARIANT         object
# TRANSMISSION    object
# DRIVEN_KM       object
# FUELTYPE        object
# NO_OF_OWNERS    object
# PRICE           object
# dtype: object

# %%
df.nunique()
# Out:
# LOCATION          10
# MNF_YEAR          14
# BRAND             21
# MODEL            115
# VARIANT          569
# TRANSMISSION       2
# DRIVEN_KM       3086
# FUELTYPE           4
# NO_OF_OWNERS       4
# PRICE           2506
# dtype: int64

# %%
## Size of the dataset
df.shape
# Out:
# (7347, 10)

# %%
df.LOCATION.unique()
# Out:
# array(['New Delhi', 'Noida', 'Gurgaon', 'Mumbai', 'Pune', 'Bengaluru',
#        'Hyderabad', 'Chennai', 'Kolkata', 'Ahmedabad'], dtype=object)

# %%
df.BRAND.unique()
# Out:
# array(['Ford', 'Maruti', 'Mahindra', 'Toyota', 'Renault', 'Hyundai',
#        'Tata', 'MG', 'Honda', 'Audi', 'BMW', 'Jeep', 'Skoda',
#        'Volkswagen', 'Mercedes', 'Nissan', 'KIA', 'Landrover', 'Jaguar',
#        'Datsun', 'Fiat'], dtype=object)

# %%
df.MODEL.unique()
# Out:
# array(['Ecosport', 'Vitara Brezza', 'XUV500', 'Innova', 'Duster',
#        'S Cross', 'Innova Crysta', 'Ertiga', 'Creta', 'Hexa', 'Thar',
#        'NEXON', 'HECTOR', 'TUV300', 'Eeco', 'VENUE', 'WR-V', 'Fortuner',
#        'Q5', 'Q3', 'X1', 'Compass', 'Tucson New', 'Swift Dzire', 'Ciaz',
#        'Verna', 'Etios', 'Amaze', 'Dzire', 'City', 'Rapid', 'Figo Aspire',
#        'Xcent', 'TIGOR', 'Vento', 'YARIS', '3 Series', '5 Series',
#        'Benz E Class', 'X3', 'Corolla Altis', 'A6', 'A3',
#        'Benz CLA Class', 'Superb', 'S PRESSO', 'IGNIS', 'Swift', 'Baleno',
#        'Elite i20', 'Grand i10', 'Alto K10', 'Tiago', 'Etios Liva', 'Eon',
#        'Wagon R 1.0', 'Celerio', 'Ritz', 'Kwid', 'ALTROZ', 'i20', 'Alto',
#        'Jazz', 'Brio', 'i20 Active', 'Alto 800', 'Polo', 'i10',
#        'New  Wagon-R', 'A Star', 'New Elantra', 'A4', 'Scorpio',
#        'Terrano', 'Zen Estilo', 'NEW SANTRO', 'SELTOS', 'Harrier',
#        'TRIBER', 'XL6', 'CRV', 'Ameo', 'Civic', 'Glanza', 'Bolero',
#        'BR-V', 'Benz B Class', 'Freelander 2', 'Benz GLC CLASS',
#        'Santa Fe', 'Jetta', 'Octavia', 'Camry', 'XF', 'Micra',
#        'GRAND I10 NIOS', 'Wagon R Stingray', 'Nano', 'MARAZZO', 'XUV 3OO',
#        'HECTOR PLUS', 'Kuv100', 'Laura', 'FREESTYLE', 'Redi Go', 'Figo',
#        'Micra Active', 'New Figo', 'OMNI E', 'Wagon R Duo', 'Grand Punto',
#        'Captur', 'Go Plus', 'KUV 100 NXT', 'Celerio X'], dtype=object)

# %%
df.MNF_YEAR.unique()
# Out:
# array([2018, 2016, 2019, 2013, 2015, 2017, 2014, 2020, 2021, 2011, 2012,
#        2010, 2009, 2008])

# %%
df.VARIANT.unique()
print(len(df.VARIANT.unique()))
# Out:
# 569

# %%
df.TRANSMISSION.unique()
# Out:
# array(['Manual', 'Automatic', nan], dtype=object)

# %%
df.NO_OF_OWNERS.unique()
# Out:
# array(['1st Owner', '2nd Owner', '3rd Owner', '4th Owner'], dtype=object)

# %%
df.FUELTYPE.unique()
# Out:
# array(['Diesel', 'Petrol', 'Petrol + CNG', 'Petrol + LPG'], dtype=object)

# %%
df.select_dtypes(include=['object']).columns  #categorical column check
# Out:
# Index(['LOCATION', 'BRAND', 'MODEL', 'VARIANT', 'TRANSMISSION', 'DRIVEN_KM',
#        'FUELTYPE', 'NO_OF_OWNERS', 'PRICE'],
#       dtype='object')

# %%
columns = ['LOCATION', 'BRAND', 'MODEL', 'VARIANT', 'TRANSMISSION', 'DRIVEN_KM','FUELTYPE', 'NO_OF_OWNERS', 'PRICE']
for i in df.columns:
    print(f"{i}: \n")
    print(df[i].value_counts())
    print("----------------")
    print(f" There are {len(df[i].value_counts())} values in column {i}")
    print("-------------------")
    print("\n")
# Out:
# LOCATION:
#
# Noida        1075
# Gurgaon      1075
# New Delhi    1075
# Mumbai       1048
# Pune          798
# Bengaluru     649
# Chennai       629
# Ahmedabad     480
# Kolkata       304
# Hyderabad     214
# Name: LOCATION, dtype: int64
# ----------------
#  There are 10 values in column LOCATION
# -------------------
#
#
# MNF_YEAR:
#
# 2017    1326
# 2018    1220
# 2019     946
# 2016     920
# 2015     892
# 2014     774
# 2013     587
# 2020     383
# 2012     121
# 2021      88
# 2011      42
# 2010      25
# 2009      17
# 2008       6
# Name: MNF_YEAR, dtype: int64
# ----------------
#  There are 14 values in column MNF_YEAR
# -------------------
#
#
# BRAND:
#
# Maruti        3255
# Hyundai       1263
# Ford           767
# Honda          509
# Toyota         380
# Renault        196
# Mahindra       193
# Tata           144
# Volkswagen     131
# Audi            94
# Jeep            92
# Skoda           68
# MG              58
# BMW             57
# Mercedes        57
# KIA             43
# Nissan          16
# Datsun          15
# Jaguar           5
# Landrover        3
# Fiat             1
# Name: BRAND, dtype: int64
# ----------------
#  There are 21 values in column BRAND
# -------------------
#
#
# MODEL:
#
# Ecosport         700
# Vitara Brezza    517
# Swift            426
# Baleno           353
# Swift Dzire      298
#                 ...
# Go Plus            2
# Jetta              2
# Grand Punto        1
# MARAZZO            1
# Wagon R Duo        1
# Name: MODEL, Length: 115, dtype: int64
# ----------------
#  There are 115 values in column MODEL
# -------------------
#
#
# VARIANT:
#
# VXI                       559
# VDI                       328
# 1.5TITANIUM TDCI          253
# LXI                       228
# DELTA 1.2 K12             214
#                          ...
# TRENDLINE 1.5L DIESEL       1
# MAGNA O 1.4 CRDI            1
# 1.5 i- DTEC V               1
# Highline 1.0 AT Petrol      1
# CROSS 1.4 GD                1
# Name: VARIANT, Length: 569, dtype: int64
# ----------------
#  There are 569 values in column VARIANT
# -------------------
#
#
# TRANSMISSION:
#
# Manual       5990
# Automatic    1336
# Name: TRANSMISSION, dtype: int64
# ----------------
#  There are 2 values in column TRANSMISSION
# -------------------
#
#
# DRIVEN_KM:
#
# 30,048 km      11
# 69,462 km      11
# 1,95,568 km    11
# 79,372 km      10
# 32,872 km      10
#                ..
# 39,230 km       1
# 33,310 km       1
# 46,578 km       1
# 62,505 km       1
# 42,958 km       1
# Name: DRIVEN_KM, Length: 3086, dtype: int64
# ----------------
#  There are 3086 values in column DRIVEN_KM
# -------------------
#
#
# FUELTYPE:
#
# Petrol          4004
# Diesel          3308
# Petrol + CNG      34
# Petrol + LPG       1
# Name: FUELTYPE, dtype: int64
# ----------------
#  There are 4 values in column FUELTYPE
# -------------------
#
#
# NO_OF_OWNERS:
#
# 1st Owner    5764
# 2nd Owner    1442
# 3rd Owner     135
# 4th Owner       6
# Name: NO_OF_OWNERS, dtype: int64
# ----------------
#  There are 4 values in column NO_OF_OWNERS
# -------------------
#
#
# PRICE:
#
# ₹4,93,899    18
# ₹7,57,899    16
# ₹5,37,899    15
# ₹3,92,399    15
# ₹8,08,499    15
#              ..
# ₹6,16,299     1
# ₹2,82,999     1
# ₹7,55,299     1
# ₹3,47,899     1
# ₹3,84,599     1
# Name: PRICE, Length: 2506, dtype: int64
# ----------------
#  There are 2506 values in column PRICE
# -------------------

# %%
df.isnull().sum()
# Out:
# LOCATION         0
# MNF_YEAR         0
# BRAND            0
# MODEL            0
# VARIANT          0
# TRANSMISSION    21
# DRIVEN_KM        0
# FUELTYPE         0
# NO_OF_OWNERS     0
# PRICE            0
# dtype: int64

# %%
df['TRANSMISSION'].fillna(df['TRANSMISSION'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# LOCATION        0
# MNF_YEAR        0
# BRAND           0
# MODEL           0
# VARIANT         0
# TRANSMISSION    0
# DRIVEN_KM       0
# FUELTYPE        0
# NO_OF_OWNERS    0
# PRICE           0
# dtype: int64

# %%
driven_km =[]
for i in df['DRIVEN_KM']:
    driven_km.append(i.split('km')[0].strip())

# %%
driven_km
# Out:
# ['55,399',
#  '65,904',
#  '27,968',
#  '21,014',
#  '71,669',
#  '47,047',
#  '66,143',
#  '21,181',
#  '35,791',
#  '55,571',
#  '27,117',
#  '24,494',
#  '34,263',
#  '8,278',
#  '59,216',
#  '20,895',
#  '76,128',
#  '85,030',
#  '2,38,590',
#  '35,874',
#  '27,334',
#  '8,162',
#  '25,951',
#  '22,764',
#  '56,913',
#  '26,759',
#  '99,872',
#  '64,745',
#  '83,557',
#  '37,178',
#  '70,744',
#  '43,343',
#  '49,331',
#  '78,340',
#  '96,631',
#  '98,659',
#  '50,957',
#  '57,226',
#  '1,13,209',
#  '70,078',
#  '65,686',
#  '49,808',
#  '66,826',
#  '68,594',
#  '31,293',
#  '73,781',
#  '36,223',
#  '30,880',
#  '35,658',
#  '24,300',
#  '20,958',
#  '50,193',
#  '80,746',
#  '79,047',
#  '26,310',
#  '42,650',
#  '38,499',
#  '14,720',
#  '1,58,147',
#  '1,19,813',
#  '16,221',
#  '85,146',
#  '83,470',
#  '63,967',
#  '53,833',
#  '38,537',
#  '66,178',
#  '17,482',
#  '85,726',
#  '66,930',
#  '60,527',
#  '60,548',
#  '70,467',
#  '62,181',
#  '92,342',
#  '74,359',
#  '95,377',
#  '57,653',
#  '82,792',
#  '41,884',
#  '63,967',
#  '53,833',
#  '82,792',
#  '37,720',
#  '10,294',
#  '25,580',
#  '95,377',
#  '41,884',
#  '21,628',
#  '48,097',
#  '1,21,229',
#  '53,545',
#  '86,460',
#  '53,460',
#  '45,761',
#  '3,537',
#  '24,448',
#  '24,876',
#  '35,434',
#  '52,649',
#  '2,38,590',
#  '35,874',
#  '21,181',
#  '55,571',
#  '20,895',
#  '27,117',
#  '24,494',
#  '71,669',
#  '47,047',
#  '66,143',
#  '85,030',
#  '22,764',
#  '83,557',
#  '73,781',
#  '37,178',
#  '43,343',
#  '49,331',
#  '31,293',
#  '70,078',
#  '70,744',
#  '85,503',
#  '36,241',
#  '81,973',
#  '70,873',
#  '58,177',
#  '85,694',
#  '81,766',
#  '31,468',
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (20,20))
sns.countplot(x = df['MODEL'],hue = df['TRANSMISSION'])
plt.xticks(rotation=90)
plt.show()

# %%
#The most demanded brand is Maruti followed by Hyundai and Honda. Manual cars are more in count, automatic cars are in demand

# %%
plt.figure(figsize = (10,10))
sns.countplot(x = df['NO_OF_OWNERS'],hue = df['TRANSMISSION'])
plt.xticks(rotation=90)
plt.show()

# %%
#Dzire are more in counts than any other models for used cars

# %%
plt.figure(figsize = (10,10))
sns.countplot(x = df['FUELTYPE'],hue = df['TRANSMISSION'])
plt.xticks(rotation=90)
plt.show()

# %%
#Very less people wants to become 3rd owner

# %%
columns = ['MNF_YEAR', 'DRIVEN_KM', 'PRICE']
plt.figure(figsize = (9,9))
graph = 1
for i in columns:
    if graph <=3:
        plt.subplot(3,1,graph)
        sns.distplot(df[i])
        plt.xlabel(i)
        graph += 1
plt.show()

# %%
df.PRICE.hist(bins =10,figsize=(20,5), color ="blue")
plt.axvline(np.mean(df.PRICE), linewidth = 7, color = "red", label = "mean PRICE")
plt.xlabel("PRICE")
plt.ylabel("count")
plt.legend()
plt.show()
print("Statistical info of PRICE :\n",\
      df.PRICE.describe())
# Out:
# Statistical info of PRICE :
#  count    7.347000e+03
# mean     7.016647e+05
# std      3.786335e+05
# min      1.907990e+05
# 25%      4.434490e+05
# 50%      6.022990e+05
# 75%      8.268990e+05
# max      3.472299e+06
# Name: PRICE, dtype: float64

# %%
#Mean of the PRICE is  Rs:7.016647

# %%
df.DRIVEN_KM.hist(bins =10,figsize=(20,5), color ="blue")
plt.axvline(np.mean(df.DRIVEN_KM), linewidth = 7, color = "red", label = "mean DRIVEN_KM")
plt.xlabel("DRIVEN_KM")
plt.ylabel("count")
plt.legend()
plt.show()
print("Statistical info of DRIVEN_KM :\n",\
      df.DRIVEN_KM.describe())
# Out:
# Statistical info of DRIVEN_KM :
#  count      7347.000000
# mean      50697.382469
# std       36833.148858
# min          19.000000
# 25%       25723.000000
# 50%       44239.000000
# 75%       68594.000000
# max      686033.000000
# Name: DRIVEN_KM, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x = "LOCATION",y = "PRICE", data = df, palette = "rainbow")
plt.axhline(np.mean(df.PRICE), color = "b", linestyle="dashed", linewidth=3)
plt.title("LOCATION Vs PRICE", fontsize = 35)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.barplot(x = "MNF_YEAR",y = "PRICE", data = df, palette = "rainbow")
plt.axhline(np.mean(df.PRICE), color = "b", linestyle="dashed", linewidth=2)
plt.title("MNF_YEAR Vs PRICE", fontsize = 35)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.barplot(x = "BRAND",y = "PRICE", data = df, palette = "rainbow")
plt.axhline(np.mean(df.PRICE), color = "b", linestyle="dashed", linewidth=2)
plt.title("BRAND Vs PRICE", fontsize = 35)
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['LOCATION', 'BRAND', 'MODEL', 'VARIANT', 'TRANSMISSION', 'FUELTYPE',
#        'NO_OF_OWNERS'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression,Lasso,LassoCV,Ridge,RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
columns = ['MNF_YEAR','LOCATION','BRAND','MODEL','VARIANT','TRANSMISSION','FUELTYPE','NO_OF_OWNERS']
lec = LabelEncoder()
for i in columns:
    df[i] = df[i].astype('str')
    df[i]=  lec.fit_transform(df[i])

# %%
df
# Out:
#       LOCATION  MNF_YEAR  BRAND  MODEL  VARIANT  TRANSMISSION  DRIVEN_KM  \
# 0            7        10      4     33       81             1      55399
# 1            7         8     13     98      444             1      65904
# 2            7         8      4     33       89             1      27968
# 3            7        11     12    108      483             1      21014
# 4            7         5     12    108      489             1      71669
# ...        ...       ...    ...    ...      ...           ...        ...
# 7342         0        10     12     59      299             1      36487
# 7343         0         9     13     37      446             1      44087
# 7344         0        11     12    108      487             1      57455
# 7345         0         9      4     33       91             1      59877
# 7346         0         5     19     55      152             1     281379
#
#       FUELTYPE  NO_OF_OWNERS    PRICE
# 0            0             0   827999
# 1            0             0   655999
# 2            1             0   681699
# 3            0             1  1531399
# 4            0             0   578099
# ...        ...           ...      ...
# 7342         1             0   420299
# 7343         0             0   784099
# 7344         0             0  1157799
# 7345         0             1   756199
# 7346         0             1   700099
#
# [7347 rows x 10 columns]

# %%
df.describe()
# Out:
#           LOCATION     MNF_YEAR        BRAND        MODEL      VARIANT  \
# count  7347.000000  7347.000000  7347.000000  7347.000000  7347.000000
# mean      5.050088     8.457874    10.548523    54.181435   310.393086
# std       2.865806     2.210096     4.792700    32.994681   162.773309
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     7.000000     6.000000    29.000000   161.000000
# 50%       6.000000     9.000000    13.000000    43.000000   330.000000
# 75%       8.000000    10.000000    13.000000    87.000000   456.000000
# max       9.000000    13.000000    20.000000   114.000000   568.000000
#
#        TRANSMISSION      DRIVEN_KM     FUELTYPE  NO_OF_OWNERS         PRICE
# count   7347.000000    7347.000000  7347.000000   7347.000000  7.347000e+03
# mean       0.818157   50697.382469     0.554648      0.235470  7.016647e+05
# std        0.385741   36833.148858     0.507071      0.470854  3.786335e+05
# min        0.000000      19.000000     0.000000      0.000000  1.907990e+05
# 25%        1.000000   25723.000000     0.000000      0.000000  4.434490e+05
# 50%        1.000000   44239.000000     1.000000      0.000000  6.022990e+05
# 75%        1.000000   68594.000000     1.000000      0.000000  8.268990e+05
# max        1.000000  686033.000000     3.000000      3.000000  3.472299e+06

# %%
plt.figure(figsize = (20,30))
graph  = 1
for i in df.columns:
    if graph <=10:
        plt.subplot(5,2,graph)
        sns.distplot(df[i])
        plt.xlabel(i)
        plt.xticks(rotation = 90)
        graph += 1
plt.show()

# %%
df.corr()
# Out:
#               LOCATION  MNF_YEAR     BRAND     MODEL   VARIANT  TRANSMISSION  \
# LOCATION      1.000000 -0.126667 -0.009513  0.028520 -0.012851     -0.082146
# MNF_YEAR     -0.126667  1.000000 -0.012289 -0.055556 -0.032538     -0.113735
# BRAND        -0.009513 -0.012289  1.000000  0.145639  0.439759      0.071853
# MODEL         0.028520 -0.055556  0.145639  1.000000  0.262313      0.037118
# VARIANT      -0.012851 -0.032538  0.439759  0.262313  1.000000      0.099930
# TRANSMISSION -0.082146 -0.113735  0.071853  0.037118  0.099930      1.000000
# DRIVEN_KM     0.070445 -0.476426  0.110262  0.041829  0.035397      0.048631
# FUELTYPE     -0.202259  0.246726 -0.019730 -0.225953 -0.038577     -0.061934
# NO_OF_OWNERS -0.048590 -0.162747 -0.068524 -0.051767 -0.051047     -0.111983
# PRICE         0.097859  0.344068 -0.085085  0.009919 -0.177474     -0.470751
#
#               DRIVEN_KM  FUELTYPE  NO_OF_OWNERS     PRICE
# LOCATION       0.070445 -0.202259     -0.048590  0.097859
# MNF_YEAR      -0.476426  0.246726     -0.162747  0.344068
# BRAND          0.110262 -0.019730     -0.068524 -0.085085
# MODEL          0.041829 -0.225953     -0.051767  0.009919
# VARIANT        0.035397 -0.038577     -0.051047 -0.177474
# TRANSMISSION   0.048631 -0.061934     -0.111983 -0.470751
# DRIVEN_KM      1.000000 -0.386814      0.067003 -0.099300
# FUELTYPE      -0.386814  1.000000      0.014515 -0.207758
# NO_OF_OWNERS   0.067003  0.014515      1.000000  0.011244
# PRICE         -0.099300 -0.207758      0.011244  1.000000

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(),annot = True, cmap = 'RdYlGn' )
plt.show()

# %%
#checking outliers

# %%
plt.figure(figsize = (20,30))
graph  = 1
for i in df.columns:
    if graph <=10:
        plt.subplot(5,2,graph)
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.xticks(rotation = 90)
        graph += 1
plt.show()

# %%
df['DRIVEN_KM'] = np.log(df['DRIVEN_KM'])

# %%
sns.distplot(df['DRIVEN_KM'])
# Out:
# <AxesSubplot:xlabel='DRIVEN_KM', ylabel='Density'>

# %%
df.skew()
# Out:
# LOCATION       -0.269912
# MNF_YEAR       -0.354226
# BRAND          -0.112504
# MODEL           0.229807
# VARIANT        -0.247958
# TRANSMISSION   -1.650037
# DRIVEN_KM      -1.404296
# FUELTYPE       -0.097633
# NO_OF_OWNERS    1.875180
# PRICE           1.803764
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
skewed_features = ['DRIVEN_KM']
scaler = PowerTransformer(method='yeo-johnson')

# %%
df[skewed_features] = scaler.fit_transform(df[skewed_features].values)
df[skewed_features].head()
# Out:
#    DRIVEN_KM
# 0   0.363320
# 1   0.633691
# 2  -0.564012
# 3  -0.892849
# 4   0.769703

# %%
df['DRIVEN_KM'].skew()
# Out:
# 0.035135061367640955

# %%
x = df.drop('PRICE',axis=1)
y= df['PRICE']

# %%
x.shape,y.shape
# Out:
# ((7347, 9), (7347,))

# %%
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       LOCATION  MNF_YEAR     BRAND     MODEL   VARIANT  TRANSMISSION  \
# 0     0.680452  0.697812 -1.366447 -0.642009 -1.409375      0.471444
# 1     0.680452 -0.207188  0.511537  1.328140  0.820872      0.471444
# 2     0.680452 -0.207188 -1.366447 -0.642009 -1.360224      0.471444
# 3     0.680452  1.150312  0.302872  1.631240  1.060485      0.471444
# 4     0.680452 -1.564687  0.302872  1.631240  1.097349      0.471444
# ...        ...       ...       ...       ...       ...           ...
# 7342 -1.762308  0.697812  0.302872  0.146051 -0.069998      0.471444
# 7343 -1.762308  0.245312  0.511537 -0.520769  0.833160      0.471444
# 7344 -1.762308  1.150312  0.302872  1.631240  1.085061      0.471444
# 7345 -1.762308  0.245312 -1.366447 -0.642009 -1.347936      0.471444
# 7346 -1.762308 -1.564687  1.763526  0.024811 -0.973156      0.471444
#
#       DRIVEN_KM  FUELTYPE  NO_OF_OWNERS
# 0      0.363320 -1.093902     -0.500126
# 1      0.633691 -1.093902     -0.500126
# 2     -0.564012  0.878343     -0.500126
# 3     -0.892849 -1.093902      1.623818
# 4      0.769703 -1.093902     -0.500126
# ...         ...       ...           ...
# 7342  -0.227998  0.878343     -0.500126
# 7343   0.029931 -1.093902     -0.500126
# 7344   0.418825 -1.093902     -0.500126
# 7345   0.482505 -1.093902      1.623818
# 7346   3.554702 -1.093902      1.623818
#
# [7347 rows x 9 columns]

# %%
#model building

# %%
score = 0
for i in range(0,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .30, random_state = i)
    rf = RandomForestRegressor()
    rf.fit(x_train,y_train)
    y_pred = rf.predict(x_test)
    tempscore = r2_score(y_test,y_pred)
    if tempscore > score:
        score= tempscore
        best_rstate=i

print(f"Best Accuracy {score*100} found on randomstate {best_rstate}")
# Out:
# Best Accuracy 98.55411073750815 found on randomstate 47

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .30, random_state = best_rstate)

# %%
lr=LinearRegression()
dtr=DecisionTreeRegressor()
knn=KNeighborsRegressor()
rf=RandomForestRegressor()
AdaBoost=AdaBoostRegressor()
lasso = Lasso()
ridge  = Ridge(alpha=1, random_state=47)

# %%
algo=[lr,dtr,rf,knn,AdaBoost,lasso,ridge]
acc_models={}
for model in algo:
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print("-"*60)
    acc_models[model]=round(r2_score(y_test,y_pred)*100,1)
    print(f"The model {model} has:: \n\t Accuracy :: {round(r2_score(y_test,y_pred)*100,1)}% \n\t Mean Absolute Error is :: {mean_absolute_error(y_test,y_pred)} \n\t Mean Squared Error is :: {mean_squared_error(y_test,y_pred)} \n\t Root Mean Squared Error is :: {np.sqrt(mean_squared_error(y_test,y_pred))}")
    print("-"*100)
    print("\n")
# Out:
# ------------------------------------------------------------
# The model LinearRegression() has::
# 	 Accuracy :: 42.9%
# 	 Mean Absolute Error is :: 206263.87581398536
# 	 Mean Squared Error is :: 82916984991.83685
# 	 Root Mean Squared Error is :: 287953.0951245999
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model DecisionTreeRegressor() has::
# 	 Accuracy :: 98.5%
# 	 Mean Absolute Error is :: 15619.891156462585
# 	 Mean Squared Error is :: 2149360295.5102043
# 	 Root Mean Squared Error is :: 46361.193853374876
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model RandomForestRegressor() has::
# 	 Accuracy :: 98.7%
# 	 Mean Absolute Error is :: 21357.359650685674
# 	 Mean Squared Error is :: 1885202100.799576
# 	 Root Mean Squared Error is :: 43418.914090515624
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model KNeighborsRegressor() has::
# 	 Accuracy :: 81.5%
# 	 Mean Absolute Error is :: 94510.73015873016
# 	 Mean Squared Error is :: 26899164475.64626
# 	 Root Mean Squared Error is :: 164009.647507841
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model AdaBoostRegressor() has::
# 	 Accuracy :: 53.7%
# 	 Mean Absolute Error is :: 216962.40465457866
# 	 Mean Squared Error is :: 67240048909.692505
# 	 Root Mean Squared Error is :: 259306.8624423436
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model Lasso() has::
# 	 Accuracy :: 42.9%
# 	 Mean Absolute Error is :: 206263.48169661412
# 	 Mean Squared Error is :: 82916991969.97801
# 	 Root Mean Squared Error is :: 287953.1072414014
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------
# The model Ridge(alpha=1, random_state=42) has::
# 	 Accuracy :: 42.9%
# 	 Mean Absolute Error is :: 206254.8778955228
# 	 Mean Squared Error is :: 82916945795.08788
# 	 Root Mean Squared Error is :: 287953.0270635957
# ----------------------------------------------------------------------------------------------------

# %%
acc_models
# Out:
# {LinearRegression(): 42.9,
#  DecisionTreeRegressor(): 98.5,
#  RandomForestRegressor(): 98.7,
#  KNeighborsRegressor(): 81.5,
#  AdaBoostRegressor(): 53.7,
#  Lasso(): 42.9,
#  Ridge(alpha=1, random_state=42): 42.9}

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
sns.regplot(y_test,y_pred)
plt.xlabel("Actual Test Data")
plt.ylabel("Predicted Data")
plt.tight_layout()

# %%
#hyperparameter tuning

# %%
param_grid = [
    {"bootstrap": [True, False],
     "criterion": ["mse", "mae"],
     "n_estimators"      : [10,20,30,50,100],
     "max_features"      : ["auto", "sqrt", "log2"],
     "min_samples_split" : [2,4,8],
    }
]

rf = RandomForestRegressor(random_state=best_rstate)

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

grid_search.fit(x_train,y_train)
final_model = grid_search.best_estimator_
final_model
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# RandomForestRegressor(bootstrap=False, max_features='sqrt', min_samples_split=4,
#                       random_state=47)

# %%
rfr = RandomForestRegressor(bootstrap=False,max_features='sqrt', random_state=42 )
rfr.fit(x_train, y_train)
y_pred = rfr.predict(x_test)
score =  r2_score(y_test,y_pred)
score
# Out:
# 0.9882643696604654

# %%
import pickle
filename = 'Car_Prediction.pickle'
pickle.dump(rfr,open(filename,'wb'))

# %%
a = np.array(y_test)
predicted = np.array(rfr.predict(x_test))
new_df = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
new_df
# Out:
#       Original  Predicted
# 0       443499   437759.0
# 1       564499   564499.0
# 2       413799   413799.0
# 3       274799   292299.0
# 4      1176099  1176099.0
# ...        ...        ...
# 2200    767999   766297.0
# 2201    465699   465699.0
# 2202    873999   873999.0
# 2203   1030399  1030399.0
# 2204    267799   267799.0
#
# [2205 rows x 2 columns]
